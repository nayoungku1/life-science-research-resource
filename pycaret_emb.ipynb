# %%
import pandas as pd

# %%
from pycaret.classification import *

# %%
# 예제 데이터셋 로드
X = pd.read_csv("./data/vector_100_embeding_X.csv")
y = pd.read_csv("./data/label_encoded_y.csv")

# %%
# 환경 설정
setup_clf = setup(data=X, target=y["SUBCLASS"], session_id=123,
                  normalize=True,  # 정규화 (Min-Max 스케일링)
                  transformation=True,  # 분포 변환 (예: Box-Cox)
                  normalize_method='minmax')  # 정규화 방법 지정
# Out:
# <style type="text/css">
# #T_ba6a4_row8_col1, #T_ba6a4_row12_col1, #T_ba6a4_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ba6a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba6a4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ba6a4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba6a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba6a4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ba6a4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ba6a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba6a4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ba6a4_row1_col1" class="data row1 col1" >SUBCLASS</td>
#     </tr>
#     <tr>
# ...

# %%
best_models = compare_models()
# Out:
# <style type="text/css">
# #T_debd2 th {
#   text-align: left;
# }
# ...

# %%
# 하이퍼파라미터 출력
print(best_models.get_params())
# Out:
# {'bootstrap': False, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 123, 'verbose': 0, 'warm_start': False}

# %%
# 튜닝 결과 반환
tuned_model, tuner = tune_model(best_models, return_tuner=True)

# 모든 시도된 하이퍼파라미터와 결과 확인
results = pd.DataFrame(tuner.cv_results_)
print(results)
# Out:
# <style type="text/css">
# #T_d8a7d_row10_col0, #T_d8a7d_row10_col1, #T_d8a7d_row10_col2, #T_d8a7d_row10_col3, #T_d8a7d_row10_col4, #T_d8a7d_row10_col5, #T_d8a7d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d8a7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8a7d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d8a7d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d8a7d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d8a7d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d8a7d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d8a7d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d8a7d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
