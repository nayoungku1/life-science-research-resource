# %%
import pandas as pd
import numpy as np
import random

# %%
seed = 42

# %%
np.random.seed(seed)
random.seed(seed)

# %%
# 예제 데이터셋 로드
X = pd.read_csv("./data/train.csv")
y = pd.read_csv("./data/label_encoded_y.csv")
X_test = pd.read_csv("./data/test.csv")

# %%
X = X.drop(["ID", "SUBCLASS"], axis = 1)

# %%
X.shape
# Out:
# (6201, 4384)

# %%
X
# Out:
#         A2M AAAS AADAT AARS1 ABAT ABCA1 ABCA2 ABCA3 ABCA4 ABCA5  ... ZNF292  \
# 0        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 1        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 2     R895R   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 3        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 4        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# ...     ...  ...   ...   ...  ...   ...   ...   ...   ...   ...  ...    ...
# 6196     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6197     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6198     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6199     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6200     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
#
#      ZNF365 ZNF639 ZNF707 ZNFX1 ZNRF4 ZPBP ZW10  ZWINT ZYX
# 0        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 1        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 2        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 3        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 4        WT     WT     WT    WT    WT   WT   WT     WT  WT
# ...     ...    ...    ...   ...   ...  ...  ...    ...  ..
# 6196     WT     WT     WT    WT    WT   WT   WT     WT  WT
# 6197     WT     WT     WT    WT    WT   WT   WT     WT  WT
# 6198     WT     WT     WT    WT    WT   WT   WT  T181S  WT
# 6199     WT     WT     WT    WT    WT   WT   WT     WT  WT
# 6200     WT     WT     WT    WT    WT   WT   WT     WT  WT
#
# [6201 rows x 4384 columns]

# %%
X["A2M"].unique()
# Out:
# array(['WT', 'R895R', 'E1462K', 'K289T', 'I175F', 'D533D', 'L903L',
#        'S660R', 'P799S', 'L621P', 'M713I', 'A615A', 'R586*',
#        'Q1051H D152D', 'D638N', 'I984S', 'F352S', 'L1214L F572L',
#        'R1297R', 'N124N', 'I822I F229L', 'I481N', 'A1061V I1056I',
#        'S781S', 'L19P', 'E153K', 'T885A', 'F495L', 'M121I', 'D897H',
#        'H582H', 'L311P', 'D641E', 'S63F A79A', 'S1249F',
#        'E1311K E342K R147C E1311K E342K R147C', 'T411S', 'T1027T R719H',
#        'R360R', 'R853R', 'V207L', 'V206V', 'R732Q', 'C1321Y I848I P529H',
#        'V1255V V814V V551M', 'R174H', 'L670L', 'S136*', 'I175I', 'Y1104D',
#        'P92T', 'F1389F T1239T V129V L13I', 'A788A', 'S782C', 'A1108T',
#        'P380Q', 'S202S', 'L1067I', 'K1176M', 'Y1216Y', 'G852R', 'K1336K',
#        'I1091T', 'L1101L', 'S785P', 'Y1055C', 'S1210S', 'T1229S', 'G69E',
#        'Q1220H', 'V978V', 'E1137Q', 'P700A', 'S1102S S150S', 'F1028V',
#        'M121V', 'R1122H', 'L1008L', 'H156Y I175I', 'P36S', 'G1094V',
#        'P463P', 'V120V', 'N1038T', 'F365L', 'T728M', 'P157P',
#        'R732Q G280G S191Y', 'E737E', 'P969S E840*', 'G69R',
#        'L965R L461L E113*', 'D82D', 'L606L', 'K625K', 'S1071S', 'G367G',
#        'S276F', 'I1091V', 'T1285I', 'H446N', 'E184D', 'M1385T', 'A1043T',
#        'L578L', 'W1069* S710S', 'G706G T548I R174H', 'R1034S', 'S593S',
#        'V148V', 'N1413K', 'D1420N', 'K271N N159Y', 'F834F F155I', 'S351A',
#        'P1306Q', 'R1031Q', 'P759T', 'E518G', 'P1438P', 'L1324L', 'C48R',
#        'Q1425*', 'S571R', 'R147H', 'M1314I F1248L A176T', 'S525F',
#        'F219F', 'G1310G', 'D282N R147C', 'R147C', 'S525S', 'E1311K',
#        'F102F', 'W739*', 'L1324I', 'P1334Q', 'A1379A', 'P163S', 'D636N',
#        'S150S'], dtype=object)

# %%
# 변환 함수 정의
def mutation_count(value):
    if pd.isna(value) or value == 'WT':
        return 0
    else:
        return len(value.split())

# %%
# 각 셀의 값을 변환
X_encoded = X.map(mutation_count)

# %%
X_test = X_test.drop(['ID'], axis = 1)

# %%
# 각 셀의 값이 float형인지 확인
for column in X_test.columns:
    for value in X_test[column]:
        if isinstance(value, float):
            print(f"{column}의 {value}는 float형입니다.")
            break
# Out:
# AK2의 nan는 float형입니다.
# ATP6V1H의 nan는 float형입니다.
# CCRL2의 nan는 float형입니다.
# CFP의 nan는 float형입니다.
# CNOT2의 nan는 float형입니다.
# CRAT의 nan는 float형입니다.
# DPYSL4의 nan는 float형입니다.
# GUK1의 nan는 float형입니다.
# IER3의 nan는 float형입니다.
# INHBB의 nan는 float형입니다.
# KCNH1의 nan는 float형입니다.
# MYL1의 nan는 float형입니다.
# NDUFV1의 nan는 float형입니다.
# NUDT4의 nan는 float형입니다.
# POLD2의 nan는 float형입니다.
# PTCH1의 nan는 float형입니다.
# PTGES3의 nan는 float형입니다.
# RBM5의 nan는 float형입니다.
# SCAMP1의 nan는 float형입니다.
# SCNN1A의 nan는 float형입니다.
# SLC25A28의 nan는 float형입니다.
# SYBU의 nan는 float형입니다.
# TARS1의 nan는 float형입니다.
# TMEM97의 nan는 float형입니다.
# TNFAIP6의 nan는 float형입니다.

# %%
X_test["AK2"].unique()
# Out:
# array(['WT', 'A36P', nan, 'K181N K173N K133N K139N', 'M237I',
#        'G205E G157E G197E G163E', 'I131I I125I I165I I173I',
#        'S208S S200S S160S S166S', 'I173I I125I I131I I165I',
#        'H143D H183D H149D H191D', 'P208P P216P P174P P168P', 'A22G A70G',
#        'R122G H145Q H105Q H111Q H153Q', 'T146T T194T T152T T186T',
#        'A4A A52A', 'G163E G197E G205E G157E', 'P208P P216P P168P P174P',
#        'A7G A55G', 'P174A P216A P208A P168A', 'Y193F Y201F Y159F Y153F',
#        'A36G', 'T47P T41P T89P', 'P23P'], dtype=object)

# %%
X_test_encoded = X_test.map(mutation_count)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_encoded, y, stratify=y, 
                                                  test_size=0.2, random_state=seed)

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test_encoded)

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
X_feature_wise = X_train_scaled.T
corr_matrix = np.corrcoef(X_feature_wise)
# Out:
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
corr_matrix = np.nan_to_num(corr_matrix, nan=0.0, posinf=1.0, neginf=-1.0)
linked = sch.linkage(corr_matrix, method='average')

# %%
plt.figure(figsize=(10, 7))
dendrogram = sch.dendrogram(linked, labels=range(corr_matrix.shape[0]))
plt.show()

# %%
f1_exam = pd.DataFrame(columns = ["max_d","macroF1", "numFeature"])

# %%
f1_exam
# Out:
# Empty DataFrame
# Columns: [max_d, macroF1, numFeature]
# Index: []

# %%
import xgboost as xgb
from sklearn.metrics import f1_score

# Create an instance of the LogisticRegression model
xgb_model = xgb.XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    random_state=42,
    use_label_encoder=False,
    eval_metric='mlogloss' 
)

# %%
# 특정 height에서 클러스터를 정의

for i in range(0, 80, 1):
    max_d = i / 10
    clusters = fcluster(linked, max_d, criterion='distance')
    
    # 각 클러스터의 대표 특성을 선택 (가장 중앙에 있는 특성 선택)
    unique_clusters = np.unique(clusters)
    selected_features_dend = []
    
    for cluster in unique_clusters:
        cluster_features = np.where(clusters == cluster)[0]
        if len(cluster_features) > 0:
            representative_feature = cluster_features[len(cluster_features) // 2]
            selected_features_dend.append(representative_feature)
    
    # 선택된 대표 특성들
    #print("Selected representative features:", selected_features_dend)
    numFeature = len(selected_features_dend)
    
    X_train_300 = X_train_scaled[:, selected_features_dend]
    X_val_300 = X_val_scaled[:, selected_features_dend]
    X_test_300 = X_test_scaled[:, selected_features_dend]

    # Train the model
    xgb_model.fit(X_train_300, y_train)
    # 예측
    y_pred = xgb_model.predict(X_val_300)
    f1 = f1_score(y_val, y_pred, average='macro')
    
    # Create a new row as a dictionary
    new_row = {'max_d': max_d, 'macroF1': f1, 'numFeature': numFeature}
    
    # Convert the new row to a DataFrame
    new_row_df = pd.DataFrame([new_row])
    
    # Use concat to add the new row to f1_exam
    f1_exam = pd.concat([f1_exam, new_row_df], ignore_index=True)
# Out:
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:18:48] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /var/folders/cv/fbnly_8d0vx9642q2wqv1r_40000gn/T/ipykernel_994/3805793708.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   f1_exam = pd.concat([f1_exam, new_row_df], ignore_index=True)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:19:16] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:19:46] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:20:18] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:20:47] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:21:16] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:21:45] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:22:14] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:22:45] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:23:14] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:23:45] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:14] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:44] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:17] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:49] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:26:19] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:26:48] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:27:16] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:27:45] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:28:13] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 26
#      23 X_test_300 = X_test_scaled[:, selected_features_dend]
#      25 # Train the model
# ---> 26 xgb_model.fit(X_train_300, y_train)
#      27 # 예측
#      28 y_pred = xgb_model.predict(X_val_300)
#
# File /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Sort f1_exam by the 'macroF1' column in descending order
f1_exam_sorted = f1_exam.sort_values(by='macroF1', ascending=False)

# %%
f1_exam_sorted

# %%
# 특정 height에서 클러스터를 정의
max_d = 1.1
clusters = fcluster(linked, max_d, criterion='distance')

# 각 클러스터의 대표 특성을 선택 (가장 중앙에 있는 특성 선택)
unique_clusters = np.unique(clusters)
selected_features_dend = []

for cluster in unique_clusters:
    cluster_features = np.where(clusters == cluster)[0]
    if len(cluster_features) > 0:
        representative_feature = cluster_features[len(cluster_features) // 2]
        selected_features_dend.append(representative_feature)

# 선택된 대표 특성들
#print("Selected representative features:", selected_features_dend)
len(selected_features_dend)
# Out:
# 4228

# %%
X_train_300 = X_train_scaled[:, selected_features_dend]
X_val_300 = X_val_scaled[:, selected_features_dend]
X_test_300 = X_test_scaled[:, selected_features_dend]

# %%
# Train the model
xgb_model.fit(X_train_300, y_train)
# Out:
# /opt/miniconda3/envs/lsrr/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [14:23:51] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# 예측
y_pred = xgb_model.predict(X_val_300)

# %%
# F1 Score 출력 (다중 클래스)
f1 = f1_score(y_val, y_pred, average='macro')  # 'micro', 'macro', 'weighted' 중 선택
print(f"F1 Score: {f1}")
# Out:
# F1 Score: 0.3531542739663705

# %%
y_test_pred = xgb_model.predict(X_test_300)

# %%
y_test_pred
# Out:
# array([21, 25, 23, ..., 25, 10,  6])

# %%
# 숫자에서 문자열로 매핑
label_mapping = {
    0: "ACC", 1: "BLCA", 2: "BRCA", 3: "CESC", 4: "COAD", 5: "DLBC", 6: "GBMLGG",
    7: "HNSC", 8: "KIPAN", 9: "KIRC", 10: "LAML", 11: "LGG", 12: "LIHC",
    13: "LUAD", 14: "LUSC", 15: "OV", 16: "PAAD", 17: "PCPG", 18: "PRAD",
    19: "SARC", 20: "SKCM", 21: "STES", 22: "TGCT", 23: "THCA", 24: "THYM",
    25: "UCEC"
}

# %%
# Convert y_test_pred (NumPy array) to a pandas Series
y_test_pred_series = pd.Series(y_test_pred)

# Use map to replace the numeric labels with strings
predictions_mapped = y_test_pred_series.map(label_mapping)

# %%
predictions_mapped
# Out:
# 0         STES
# 1         UCEC
# 2         THCA
# 3          LGG
# 4         STES
#          ...
# 2541      COAD
# 2542      PAAD
# 2543      UCEC
# 2544      LAML
# 2545    GBMLGG
# Length: 2546, dtype: object

# %%
submisson = pd.read_csv("./data/sample_submission.csv")

# %%
submisson
# Out:
#              ID SUBCLASS
# 0     TEST_0000      LGG
# 1     TEST_0001      LGG
# 2     TEST_0002      LGG
# 3     TEST_0003      LGG
# 4     TEST_0004      LGG
# ...         ...      ...
# 2541  TEST_2541      LGG
# 2542  TEST_2542      LGG
# 2543  TEST_2543      LGG
# 2544  TEST_2544      LGG
# 2545  TEST_2545      LGG
#
# [2546 rows x 2 columns]

# %%
submisson["SUBCLASS"] = predictions_mapped

# %%
from datetime import datetime
today = datetime.now()
mmdd = today.strftime("%m%d")

# %%
submisson.to_csv(f'./submit/{mmdd}_dendrogram_xgb_robust_submission.csv', encoding='UTF-8-sig', index=False)
